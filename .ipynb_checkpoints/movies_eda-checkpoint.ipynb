# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('IMDbmovies.csv')

# %%
df = df.dropna()

# %%
df[['budget_currency','budget_amount']] = df.budget.str.split(expand=True)
df[['income_currency','income_amount']] = df.worlwide_gross_income.str.split(expand=True)

df.budget_amount = pd.to_numeric(df['budget_amount'])
df.income_amount = pd.to_numeric(df['income_amount'])

df = df[df.budget_currency == "$"]

# %%
df.head()
# Out:
#      imdb_title_id                            title  \
# 1005     tt0021749                      City Lights
# 2336     tt0027977                     Modern Times
# 2687     tt0029583  Snow White and the Seven Dwarfs
# 3100     tt0031381               Gone with the Wind
# 3180     tt0031679     Mr. Smith Goes to Washington
#
#                        original_title  year date_published  \
# 1005                      City Lights  1931     1931-08-21
# 2336                     Modern Times  1936     1936-10-16
# 2687  Snow White and the Seven Dwarfs  1937     1938-07-08
# 3100               Gone with the Wind  1939     1942-09-04
# 3180     Mr. Smith Goes to Washington  1939     1940-05-03
#
#                            genre  duration country language  \
# 1005      Comedy, Drama, Romance        87     USA  English
# 2336       Comedy, Drama, Family        87     USA  English
# 2687  Animation, Family, Fantasy        83     USA  English
# 3100     Drama, History, Romance       238     USA  English
# 3180               Comedy, Drama       129     USA  English
#
#                           director  ...     budget usa_gross_income  \
# 1005               Charles Chaplin  ...  $ 1500000          $ 19181
# 2336               Charles Chaplin  ...  $ 1500000         $ 163577
# 2687  William Cottrell, David Hand  ...  $ 1499000      $ 184925486
# 3100  Victor Fleming, George Cukor  ...  $ 3977000      $ 200852579
# 3180                   Frank Capra  ...  $ 1900000         $ 144738
#
#      worlwide_gross_income metascore  reviews_from_users  \
# 1005               $ 32609      99.0               270.0
# 2336              $ 445226      96.0               262.0
# 2687           $ 184925486      95.0               229.0
# 3100           $ 402352579      97.0               808.0
# 3180              $ 144738      73.0               272.0
#
#       reviews_from_critics budget_currency budget_amount income_currency  \
# 1005                 120.0               $       1500000               $
# 2336                 146.0               $       1500000               $
# 2687                 166.0               $       1499000               $
# 3100                 183.0               $       3977000               $
# 3180                 110.0               $       1900000               $
#
#       income_amount
# 1005          32609
# 2336         445226
# 2687      184925486
# 3100      402352579
# 3180         144738
#
# [5 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(14,6))
# sns.lineplot(x=df.year, y=df.income_amount, data=df)
# sns.lineplot(x=df.year, y=df.budget_amount, data=df)
sns.regplot(x=df.income_amount, y=df.budget_amount, data=df)

# %%
fig, ax = plt.subplots(figsize=(14,6))
# sns.lineplot(x=df.year, y=df.income_amount, data=df)
# sns.lineplot(x=df.year, y=df.budget_amount, data=df)
ax.scatter(x=df.income_amount, y=df.budget_amount, s=1, alpha=0.5)
ax.set_xlim(0,1.5e5)
ax.set_ylim(0,1e8)
# Out:
# (0, 100000000.0)
