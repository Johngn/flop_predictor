# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./data/IMDbmovies.csv')

# separate currency and amount into two new columns
df[['budget_currency','budget']] = df.budget.str.split(expand=True)
df[['box_office_currency','box_office']] = df.worlwide_gross_income.str.split(expand=True)
# convert amount string to numeric
df.budget = pd.to_numeric(df['budget'])
df.box_office = pd.to_numeric(df['box_office'])

df = df[df.budget_currency == "$"]

df = df[df.year > 1980]
# df = df.dropna()
df.shape
# Out:
# (12993, 25)

# %%
df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'budget_currency',
#        'box_office_currency', 'box_office'],
#       dtype='object')

# %%
df.drop(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
       'country', 'language', 'writer','metascore',
       'production_company', 'description', 'votes',
       'usa_gross_income', 'worlwide_gross_income',
       'reviews_from_users', 'reviews_from_critics', 'budget_currency','actors',
       'box_office_currency'], axis='columns')
# Out:
#                             genre  duration                      director  \
# 4115     Comedy, Fantasy, Romance       118                 James Mangold
# 16550        Comedy, Crime, Drama       100         William Byron Hillman
# 18767            Horror, Thriller        96                Peter F. Buffa
# 19026  Adventure, Comedy, Fantasy       116                 Terry Gilliam
# 19036                       Drama        90         Frederick King Keller
# ...                           ...       ...                           ...
# 81234      Drama, Horror, Romance       122          Sitisiri Mongkolsiri
# 81239                      Action        92                  Keoni Waxman
# 81249                     Romance        92                 Don Tjernagel
# 81254                      Horror        77  Robin Entreinger, Steve Noir
# 81267            Action, Thriller       145              Lokesh Kanagaraj
#
#        avg_vote      budget  box_office
# ...

# %% [markdown]
# ## Directors
#
# Who are the most prolific directors?

# %%
df.director.value_counts()
# Out:
# Michael Curtiz      86
# Jesús Franco        85
# Lloyd Bacon         73
# William Beaudine    69
# Richard Thorpe      67
#                     ..
# Bruce Van Dusen      1
# Jay Gammill          1
# Maria Plyta          1
# Webster Batista      1
# Paul Stanley         1
# Name: director, Length: 32544, dtype: int64

# %% [markdown]
# ## Film length
#
# I want to check what features in the data are actually in any way predictive. Is it possible that there is some correlation between the length of a film and its metascore?

# %%
fig, ax = plt.subplots(figsize=(14,6))
sns.scatterplot(x=df.duration, y=df.metascore)
ax.set_xlim(60, 180)
# Out:
# (60, 180)

# %% [markdown]
# ## Adjust for inflation
#
# To compare movie budgets and box office numbers over the years we need to adjust for inflation. We will also drop films older than 1980 as the film industry has changed a lot over the years, and box office incomes from older films, even adjusted for inflation may not provide useful information. Also the vast majority of films are newer than this so not much is lost.

# %%
df
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics, budget_currency, budget_amount, income_currency, income_amount]
# Index: []
#
# [0 rows x 26 columns]

# %%
fig, ax = plt.subplots(figsize=(14,6))
sns.scatterplot(x=df.year, y=df.income_amount, data=df)
